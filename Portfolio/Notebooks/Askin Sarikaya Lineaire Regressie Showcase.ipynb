# %% [markdown]
# Voor deze notebook / showcase van geleerde technieken heb ik gebruik gemaakt van een kaggle dataset. Deze is te vinden op:
# https://www.kaggle.com/shivachandel/kc-house-data
# Daarbij is bewust gekozen voor een dataset zonder Kernels.

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
houses_data = pd.read_csv("kc_house_data.csv") # lezen van de data van een csv file genomen van kaggle in een variabele genaamd houses_data

# %%
houses_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
houses_data.shape
# Out:
# (21613, 21)

# %%
# Omdat we de  "id" en "date" niet nodig hebben voor training, verwijder ik deze 2 colummen van variabele houses_data
del houses_data['id'], houses_data['date']

# %%
houses_data.isnull().sum() #Kijken of er geen missende waardes zijn in de data, totale nummer van missende waarde per feature wordt berekend met isnull()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#corrmat = houses_data.corr()
#plt.matshow(corrmat)
#sns.heatmap(corrmat,square = True)
#cols = houses_data.columns[:10]
corr = houses_data.corr()

fig, ax = plt.subplots(figsize=(21, 21))
ax.matshow(corr)
plt.xticks(range(len(corr.columns)), corr.columns);
plt.yticks(range(len(corr.columns)), corr.columns);

pd.DataFrame(corr)
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
houses_data.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
var = 'sqft_living15'
data = pd.concat([houses_data['price'], houses_data[var]], axis=1)
data.plot.scatter(x=var, y='price', ylim=(3,9000000));

# %%
var = 'sqft_living'
data = pd.concat([houses_data['price'], houses_data[var]], axis=1)
data.plot.scatter(x=var, y='price', ylim=(3,9000000));

# %%
# Het bekijken van sterke correlaties tussen verschillende colummen zoals individueel gedaan hierboven.
sns.set()
cols = ['sqft_living', 'grade', 'sqft_above', 'view', 'bathrooms','bedrooms','sqft_basement']
sns.pairplot(houses_data[cols], height = 3.5)
plt.show();

# %%
# Het maken van een aparte variable van de price colum
y = houses_data['price']
del houses_data['price']

# %%
def train_test_split(x,y):
    x = houses_data[x]
    y = houses_data[y]
    X_train, X_test, y_train, y_test = train_test_split(houses_data, y, test_size = 0.33, random_state = 44)
    linreg = LinearRegression()
    linreg.fit(X_train, y_train)
    y_pred = linreg.predict(X_test)
    
    print(accuracy_score(y_test, y_pred))  # or you can save it in variable and return it 
    return np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
print (houses_data.shape)
print (X_train.shape, X_test.shape)
# Out:
# (21613, 18)
# (14480, 18) (7133, 18)

# %%
reg = LinearRegression(normalize = True).fit(X_train, y_train) 
# Hierboven heb ik de lineaire regressie model geinitialiseerd en vervolgens deze "gevoed" in the training data X voor training Y

# %% [markdown]
# Ons model is nu getrained op gegeven data.

# %%
reg.score(X_test, y_test) # Hier kijk ik naar de score / performance van geinitaliseerde model op de data.
# Out:
# 0.6933400399390457

# %%
importances = np.log10(abs(reg.coef_) + 1) #Nieuwe variabelen "belangrijkheid van features"
df = pd.DataFrame({'cols':X_test.columns, 'val':(importances)}) #De data in een Pandadataframe implementeren
ax = df.plot.bar(x='cols', y='val') #Soort plotbar om te laten zien welke feature de meeste "waarde" laat zien.

# %%
X = houses_data['waterfront'].values.reshape(-1, 1)  # Waarde veranderen in een numpy array. Genomen is een van de belangrijkst features hierboven gevisualiseerd.
Y = y.values.reshape(-1, 1)  # -1 geeft de calculatie van de dimensie van de rijen aan, maar wel in 1 kolom.
linear_regressor = LinearRegression()  # Een object creeren voor de klasse
linear_regressor.fit(X, Y)  # Het uitvoeren van een lineaire regressie 
plt.scatter(X, Y)

plt.plot(X, Y_pred, color='red')
plt.show()
